# %%
import pandas as pd
import statsmodels.formula.api as smf

facebook = pd.read_csv('DATA/dataset_Facebook.csv', delimiter=";")
df = facebook

# %%
facebook
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
facebook.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.head(20)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# ...

# %%
df.tail(20)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 480             86909  Photo         2           1             4         11
# 481             86491   Link         1           1             4          4
# 482             86491  Photo         3           1             3         10
# 483             86491  Photo         2           1             3          3
# 484             86491  Photo         3           1             2          7
# 485             86491   Link         1           1             2          2
# 486             85979  Photo         3           1             1         12
# 487             85979  Photo         3           1             1          2
# 488             85979  Photo         3           1             7         10
# 489             85979  Photo         3           1             7          2
# 490             85979  Photo         3           1             6         11
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf

# %%
ax = sns.lineplot(x = 'Post Month', y = 'Total Interactions', data = df)

# %%
ax = sns.lineplot(x = 'Post Weekday', y = 'Total Interactions', data = df)

# %%
ax = sns.lineplot(x = 'Post Hour', y = 'Total Interactions', data = df)

# %%
ax = sns.lineplot(x = 'Post Weekday', y = 'Lifetime Post Total Reach', data = df, hue = 'Lifetime Post Total Impressions')

# %%
ax = sns.lineplot(x = 'Post Month', y = 'Lifetime Post Total Reach', data = df, hue = 'Lifetime Post Total Reach')

# %%
ax = sns.lineplot(x = 'Lifetime Post Total Impressions', y = 'Lifetime Post Total Reach', data = df, hue = 'Post Hour')

# %%
ax =sns.scatterplot(x = 'Lifetime Post Total Impressions' , y = 'Lifetime Post Total Reach', data = df, color = 'green', marker = "p")

# %%
ax = sns.jointplot(x = 'Lifetime Post Total Impressions', y = 'Lifetime People who have liked your Page and engaged with your post', data = df, 
                   height = 10, kind = 'reg', ci = False)

# %%
ax = sns.boxplot(x = 'Post Weekday', y = 'Lifetime Post Total Reach', data = df, color = 'cyan')
ax = sns.swarmplot(x = 'Post Weekday', y = 'Lifetime Post Total Reach', data = df, color = 'red')

# %%
ax = sns.boxplot(x =  'Lifetime Post Total Reach', y = 'Day_Name', data = dataframe, color = 'cyan')
